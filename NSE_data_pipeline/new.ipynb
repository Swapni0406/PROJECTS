# %%
import requests
import pandas as pd
import io

# %%
headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'cookie':'ga=GA1.1.1137435405.1709275781; defaultLang=en; nsit=jOwr4t01SbtJMZRWVIi6HvKG; AKA_A2=A; _abck=30F73D2339CD74F8F23D33AF25BDFD89~0~...~-1~-1~-1; bm_sz=A4F22997420AFFF1DE1FE24779096E60~~4337715~4473649; ak_bmsc=456200C64AFE270437B942CD47C2DD18~000000000000000000000000000000~...; nseappid=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhcGkubnNlIiwiYXVkIjoiYXBpLm5zZSIsImlhdCI6MTcwOTU3MDczOSwiZXhwIjoxNzA5NTc3OTM5fQ.C9-9TL4-jjGxInmaHGY75WZjvjtTzVeaRj1_qz9NRmE; _ga_QJZ4447QD3=GS1.1.1709570723.7.0.1709570741.0.0.0; _ga_87M7PJ3R97=GS1.1.1709570723.9.1.1709570741.0.0.0; bm_sv=22C556534F0EEF018337ACE985F70606~~1; RT="z=1&dm=nseindia.com&si=9cd97feb-afcd-40e8-9fc3-d274b40e1e94&ss=ltd69n3a&sl=0&se=8c&tt=0&bcn=%2F%2F684d0d45.akstat.io%2F&nu=kpaxjfo&cl=nkk"',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest'
}

# %%
response = requests.get(url='https://www.nseindia.com/api/equity-stockIndices?csv=true&index=NIFTY%2050&selectValFormat=crores', headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.content
tcs_data = pd.read_csv(io.StringIO(response.content.decode('utf-8')))

# %%
tcs_data.shape
# Out:
# (51, 14)

# %%
tcs_data.head
# Out:
# <bound method NDFrame.head of      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  22,403.50  22,440.90  22,358.30      22,378.40  22,405.60
# 1         NTPC     348.00     358.30     345.75         341.75     354.35
# 2     HDFCLIFE     595.00     620.50     587.60         592.30     609.00
# 3    POWERGRID     288.00     297.00     288.00         286.85     294.60
# 4         ONGC     272.75     280.55     272.50         271.90     279.20
# 5         BPCL     625.20     643.25     620.85         625.20     641.90
# 6   BAJAJ-AUTO   8,068.75   8,225.00   8,046.65       8,041.30   8,206.00
# 7      DRREDDY   6,240.00   6,439.35   6,239.00       6,238.90   6,334.90
# 8    COALINDIA     451.85     458.00     448.05         448.50     455.20
# 9     RELIANCE   2,980.95   3,024.90   2,974.45       2,982.15   3,010.00
# 10    AXISBANK   1,099.25   1,108.90   1,093.10       1,096.70   1,105.25
# ...

# %%
tcs_data.columns
# Out:
# Index(['SYMBOL \n', 'OPEN \n', 'HIGH \n', 'LOW \n', 'PREV. CLOSE \n', 'LTP \n',
#        'CHNG \n', '%CHNG \n', 'VOLUME \n(shares)', 'VALUE \n (₹ Crores)',
#        '52W H \n', '52W L \n', '30 D   %CHNG \n',
#        '365 D % CHNG \n 03-Mar-2023'],
#       dtype='object')

# %%
tcs_data.columns = map(str.upper, tcs_data.columns.str.replace(' ', ''))

# %%
tcs_data.columns
# Out:
# Index(['SYMBOL\n', 'OPEN\n', 'HIGH\n', 'LOW\n', 'PREV.CLOSE\n', 'LTP\n',
#        'CHNG\n', '%CHNG\n', 'VOLUME\n(SHARES)', 'VALUE\n(₹CRORES)', '52WH\n',
#        '52WL\n', '30D%CHNG\n', '365D%CHNG\n03-MAR-2023'],
#       dtype='object')

# %%
tcs_data.head()
# Out:
#     SYMBOL\n     OPEN\n     HIGH\n      LOW\n PREV.CLOSE\n      LTP\n  CHNG\n  \
# 0   NIFTY 50  22,403.50  22,440.90  22,358.30    22,378.40  22,405.60   27.20
# 1       NTPC     348.00     358.30     345.75       341.75     354.35   12.60
# 2   HDFCLIFE     595.00     620.50     587.60       592.30     609.00   16.70
# 3  POWERGRID     288.00     297.00     288.00       286.85     294.60    7.75
# 4       ONGC     272.75     280.55     272.50       271.90     279.20    7.30
#
#    %CHNG\n VOLUME\n(SHARES) VALUE\n(₹CRORES)     52WH\n     52WL\n  \
# 0     0.12     29,87,94,435        23,771.60  22,440.90  16,828.35
# 1     3.69      3,80,75,510         1,347.53     358.30     166.80
# 2     2.82        72,72,987           442.31     710.60     457.80
# 3     2.70      2,31,31,460           680.57     297.00     164.03
# 4     2.68      2,22,80,353           618.35     281.15     146.50
#
#    30D%CHNG\n  365D%CHNG\n03-MAR-2023
# 0        2.40                   27.19
# ...

# %%
tcs_data.dtypes
# Out:
# SYMBOL\n                   object
# OPEN\n                     object
# HIGH\n                     object
# LOW\n                      object
# PREV.CLOSE\n               object
# LTP\n                      object
# CHNG\n                    float64
# %CHNG\n                   float64
# VOLUME\n(SHARES)           object
# VALUE\n(₹CRORES)           object
# 52WH\n                     object
# 52WL\n                     object
# 30D%CHNG\n                float64
# 365D%CHNG\n03-MAR-2023    float64
# dtype: object

# %%
tcs_data = tcs_data.replace({',': ''}, regex=True)

# %%
tcs_data.dtypes
# Out:
# SYMBOL\n                   object
# OPEN\n                     object
# HIGH\n                     object
# LOW\n                      object
# PREV.CLOSE\n               object
# LTP\n                      object
# CHNG\n                    float64
# %CHNG\n                   float64
# VOLUME\n(SHARES)           object
# VALUE\n(₹CRORES)           object
# 52WH\n                     object
# 52WL\n                     object
# 30D%CHNG\n                float64
# 365D%CHNG\n03-MAR-2023    float64
# dtype: object

# %%
tcs_data.head
# Out:
# <bound method NDFrame.head of       SYMBOL\n    OPEN\n    HIGH\n     LOW\n PREV.CLOSE\n     LTP\n  CHNG\n  \
# 0     NIFTY 50  22403.50  22440.90  22358.30     22378.40  22405.60   27.20
# 1         NTPC    348.00    358.30    345.75       341.75    354.35   12.60
# 2     HDFCLIFE    595.00    620.50    587.60       592.30    609.00   16.70
# 3    POWERGRID    288.00    297.00    288.00       286.85    294.60    7.75
# 4         ONGC    272.75    280.55    272.50       271.90    279.20    7.30
# 5         BPCL    625.20    643.25    620.85       625.20    641.90   16.70
# 6   BAJAJ-AUTO   8068.75   8225.00   8046.65      8041.30   8206.00  164.70
# 7      DRREDDY   6240.00   6439.35   6239.00      6238.90   6334.90   96.00
# 8    COALINDIA    451.85    458.00    448.05       448.50    455.20    6.70
# 9     RELIANCE   2980.95   3024.90   2974.45      2982.15   3010.00   27.85
# 10    AXISBANK   1099.25   1108.90   1093.10      1096.70   1105.25    8.55
# ...

# %%
import pandas as pd

# Sample data with date strings
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03'],
       'Open': [100, 105, 110],
       'High': [105, 115, 120],
       'Low': [95, 100, 105],
       'Close': [102, 112, 118]}

df = pd.DataFrame(data)

# Convert the 'Date' column to datetime objects
df['Date'] = pd.to_datetime(df['Date'])

print(df)
# Out:
#         Date  Open  High  Low  Close
# 0 2023-01-01   100   105   95    102
# 1 2023-01-02   105   115  100    112
# 2 2023-01-03   110   120  105    118

# %%
import yfinance as yf

reliance = yf.download("RELIANCE.NS", start="2023-01-01", end="2023-06-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
reliance['Moving_Average_50'] = reliance['Close'].rolling(window=50).mean()
reliance['Moving_Average_200'] = reliance['Close'].rolling(window=200).mean()

# %%
import matplotlib.pyplot as plt

reliance['Close'].plot(label='Close')
reliance['Moving_Average_50'].plot(label='Moving Average 50-day')
reliance['Moving_Average_200'].plot(label='Moving Average 200-day')

plt.legend()
plt.show()

# %%
import yfinance as yf

tatasteel = yf.download("TATASTEEL.NS", start="2023-01-01", end="2023-06-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tatasteel['Moving_Average_50'] = tatasteel['Close'].rolling(window=50).mean()
tatasteel['Moving_Average_200'] = tatasteel['Close'].rolling(window=200).mean()

# %%
import matplotlib.pyplot as plt

tatasteel['Close'].plot(label='Close')
tatasteel['Moving_Average_50'].plot(label='Moving Average 50-day')
tatasteel['Moving_Average_200'].plot(label='Moving Average 200-day')

plt.legend()
plt.show()

# %%
buy_signals = tatasteel['Close'] > tatasteel['Moving_Average_50']
sell_signals = tatasteel['Close'] < tatasteel['Moving_Average_50']

tatasteel['Signal'] = 0
tatasteel.loc[buy_signals, 'Signal'] = 1
tatasteel.loc[sell_signals, 'Signal'] = -1

tatasteel['Strategy_Returns'] = tatasteel['Signal'].shift(1) * tatasteel['Close'].pct_change()
cumulative_returns = (tatasteel['Strategy_Returns'] + 1).cumprod()

plt.plot(cumulative_returns)
plt.show()

# %%
# Moving Average
tatasteel['Moving_Average_50'] = tatasteel['Close'].rolling(window=50).mean()
tatasteel['Moving_Average_200'] = tatasteel['Close'].rolling(window=200).mean()

# Bollinger Bands
tatasteel['Bollinger_High'] = tatasteel['Close'].rolling(window=20).mean() + 2 * tatasteel['Close'].rolling(window=20).std()
tatasteel['Bollinger_Low'] = tatasteel['Close'].rolling(window=20).mean() - 2 * tatasteel['Close'].rolling(window=20).std()

# EMA
tatasteel['EMA_12'] = tatasteel['Close'].ewm(span=12, adjust=False).mean()
tatasteel['EMA_26'] = tatasteel['Close'].ewm(span=26, adjust=False).mean()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

tatasteel['Close'].plot(label='Close')
tatasteel['Moving_Average_50'].plot(label='Moving Average 50-day')
tatasteel['Moving_Average_200'].plot(label='Moving Average 200-day')
tatasteel['Bollinger_High'].plot(label='Bollinger High', linestyle='--')
tatasteel['Bollinger_Low'].plot(label='Bollinger Low', linestyle='--')
tatasteel['EMA_12'].plot(label='EMA 12-day')
tatasteel['EMA_26'].plot(label='EMA 26-day')

plt.legend()
plt.show()
